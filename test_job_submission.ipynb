# %% [markdown]
# # Categorum Jobs API — Getting Started
#
# This notebook walks you through the complete process of using the Categorum Jobs API, from setup to getting results back in your Google Sheet.
#
# **What you'll do:**
# 1. Link your Google Sheet containing the data you want to process
# 2. Connect to the API using your credentials
# 3. Choose a job type and configure it
# 4. Submit the job and wait for it to finish
#
# **Before you start**, make sure you have:
# - A `.env` file in this project with your `API_KEY` and `JOBS_API_BASE_URL` (see `.env.example` for the template)
# - A Google Sheet with data you want to categorise, shared with the Categorum service account
#
# Run each cell in order from top to bottom.

# %% [markdown]
# ## Step 1: Enter Your Google Sheet Link
#
# Paste the full URL of the Google Sheet you want to process below. This is the sheet that contains the text data you want the API to categorise or filter.
#
# Make sure the sheet has been shared with the Categorum service account before continuing.

# %%
SHEET_LINK = ""
if SHEET_LINK == "":
    raise ValueError("SHEET_LINK is not set. Please set it to a valid google sheet link.")

# %% [markdown]
# ## Step 2: Load Your Credentials
#
# This cell reads your API key and the server address from a `.env` file in the project folder. These are needed to prove who you are when making requests to the API.
#
# If you don't have a `.env` file yet, copy `.env.example` to `.env` and fill in your values.

# %%
from client_wrapper import JobsApiClient
from dotenv import load_dotenv, find_dotenv
import os

dotenv_path = find_dotenv()
if not dotenv_path:
    raise FileNotFoundError("Unable to locate .env file starting from the current directory upwards")
print(f"Using env file: {dotenv_path}")

load_dotenv(dotenv_path)

API_KEY = os.environ.get("API_KEY")
if not API_KEY:
    raise ValueError(f"API_KEY not found in {dotenv_path}")

JOBS_API_BASE_URL = os.environ.get("JOBS_API_BASE_URL")
if not JOBS_API_BASE_URL:
    raise ValueError(f"JOBS_API_BASE_URL not found in {dotenv_path}")

env_values = dict(os.environ)

# %% [markdown]
# ## Step 3: Connect to the API
#
# This creates a connection to the Categorum server and runs a quick check to make sure everything is working — your credentials are valid and the server is reachable.

# %%
API_BASE_URL = env_values.get("JOBS_API_BASE_URL", "https://categorum-backend-production-104303022523.europe-west2.run.app")
if API_BASE_URL.endswith("/"):
    API_BASE_URL = API_BASE_URL[:-1]

jobs_client = JobsApiClient(API_BASE_URL, API_KEY)
print(f"Targeting API at: {jobs_client.base_url}")

try:
    version_payload = jobs_client.get("/meta/version")
    print(f"API version: {version_payload}")
except Exception as e:
    print(f"Could not reach version endpoint: {e}")

try:
    jobs_list = jobs_client.get("/jobs")
    count = len(jobs_list) if isinstance(jobs_list, list) else jobs_list.get("total", "?")
    print(f"Connection OK — found {count} existing job(s)")
except Exception as e:
    print(f"Connection check failed: {e}")

# %% [markdown]
# ## Step 4: Choose a Job Type
#
# > **Caution:** Running a job will make API calls that incur costs. The default below is set to **Generate Categories**, which only produces a category list without processing every row — making it one of the cheaper options to start with. Jobs like **Catify** and **Categorise** process every row individually and will cost more, especially on large sheets.
#
# The API supports several types of jobs. Below are ready-made examples for each one — pick the one that matches what you want to do:
#
# - **Catify** — Automatically comes up with categories *and* assigns each row to one, all in a single step. Results are written back to your sheet.
# - **Generate Categories** — Looks at your data and produces a list of categories, but doesn't assign any rows. The categories are saved to a new tab in your sheet.
# - **Categorise** — Assigns each row to a category using a set of categories that already exist (e.g. from a previous "Generate Categories" run).
# - **Filter** — Answers a yes/no question about each row (e.g. "Is this about food?"). Results are saved to a new tab.
#
# Edit the fields below to match your sheet's column names and your goals. Then set `job_payload` at the bottom of the cell to whichever example you want to run.
#
# For a full description of each field in the job payload (e.g. `scope`, `data_column`, `response_column`, `worksheet_name`, `num_categories`, `overwrite`), see the **Job payload** section in `README.md`.

# %%
job_payload_catify_sample = {
    "client_sheet_link": SHEET_LINK,
    "name": "Test API Catify Run",
    "scope": "What is the topic of this discussion?",
    "job_type": "catify",
    "data_column": "Statement",
    "categorisation_model_level": "normal", # normal|economy
    "num_categories": 5,
    "response_column": "Topic"
}

job_payload_generate_categories_sample = {
    "client_sheet_link": SHEET_LINK,
    "name": "Test API Generate Categories Run",
    "scope": "What is the topic of this discussion?",
    "job_type": "generate_categories",
    "data_column": "Statement",
    "categorisation_model_level": "normal", # normal|economy
    "num_categories": 5,
    "worksheet_name": "Topic Categories"
}

job_payload_categorise_sample = {
    "client_sheet_link": SHEET_LINK,
    "name": "Test API Categorise Run",
    "scope": "What is the topic of this discussion?",
    "job_type": "categorise",
    "data_column": "Statement",
    "categorisation_model_level": "normal", # normal|economy
    "num_categories": 5,
    "response_column": "Topic",
    "worksheet_name": "Topic Categories"
}

job_payload_filter_sample = {
    "client_sheet_link": SHEET_LINK,
    "name": "Test API Catify Run",
    "scope": "Is this about food?",
    "job_type": "filter",
    "data_column": "Statement",
    "categorisation_model_level": "economy", # normal|economy
    "worksheet_name": "Food discussions",
}

job_payload=job_payload_generate_categories_sample

# %% [markdown]
# ## Step 5: Submit the Job
#
# This sends your job configuration to the API. The server will check that everything looks right and create a job record. You'll get back a response with a unique job ID that you can use to track progress.

# %%
from pprint import pprint

job_result = jobs_client.post("/jobs", json=job_payload)
print("Job created! Response:")
pprint(job_result)

# %% [markdown]
# ## Step 6: Check the Job Status
#
# After submitting, the server validates your job — for example, it checks that it can access your Google Sheet and that the columns you specified exist. This cell fetches the current status.
#
# The status should reach **"Verified"** once validation passes. If it shows **"Failed"**, something went wrong — check the error message for details.

# %%
job_id = job_result.get("id") or job_result.get("_id")
if not job_id:
    raise ValueError("Job result did not contain a job ID.")

job = jobs_client.get(f"/jobs/{job_id}")
print("Current job status:", job.get("status"))

if job.get("status").lower() == "failed":
    raise ValueError(f"Job failed with error: {job.get('error')}")

# %% [markdown]
# ## Step 7: Run the Job and Wait for Results
#
# Once the job has been verified, this cell tells the server to start processing your data. It then checks the status every 20 seconds until the job finishes (or until 5 minutes have passed).
#
# When the job completes, the results will be written directly to your Google Sheet.

# %%
import time

job_status = jobs_client.get(f"/jobs/{job_id}").get("status")
if job_status.lower() != "verified":
    raise ValueError(f"Job status is not 'Verified', current status: {job_status}")

run_result = jobs_client.post(f"/jobs/{job_id}/run")
print("Job is now running:")
pprint(run_result)

max_wait_seconds = 300
poll_interval = 20
start_time = time.time()

while True:
    job_info = jobs_client.get(f"/jobs/{job_id}")
    status = job_info.get("status")
    print(f"Status: {status}")
    if status in {"completed", "failed"}:
        print("Job finished with status:", status)
        break
    if time.time() - start_time > max_wait_seconds:
        print("Timed out after 5 minutes. You can re-run this cell to keep checking.")
        break
    time.sleep(poll_interval)
